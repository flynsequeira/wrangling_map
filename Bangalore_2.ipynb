# %% [markdown]
# # Data Wrangling Project
# > the region selected was 'bengaluru, India' which is my hometown. The dataset is as large as 600+MB. And there were a few challenges I had to face while cleaning the data, which is described below.

# %%
# Explaination at the bottom

import csv
import codecs
import pprint
import re
import xml.etree.cElementTree as ET
import sqlite3
import cerberus
import schema

# %%
OSM_PATH = "bengaluru_india.osm"
NODES_PATH = "bangalore/node.csv"
NODE_TAGS_PATH = "bangalore/node_tags.csv"
WAYS_PATH = "bangalore/way.csv"
WAY_NODES_PATH = "bangalore/way_nodes.csv"
WAY_TAGS_PATH = "bangalore/way_tags.csv"

# %%
# VALIDATION PROCESS

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
SCHEMA = schema.schema

# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']

# %% [markdown]
# ## Fixing street names
# > Here in bangalore we refer to roads using 'Main' and 'Cross' most of the time. Road names might be abbreviated to 'Rd' but you find very few 'Street' or 'Lane'
# > Secondly Some of the data might have the area name written. This is not the road name. So a data could be something like
# >> '17th Main, BTM Layout' But we need to change it to '17th Main Road'.We got to consider 2 things.
# >>> - If Road is missing from any value that has 'Main', or 'Cross', we add 'Road' <br/>
# >>> - Any value after road is removed.
#
# > Sometime the area name is given after the road name. That also is avoided in the code below

# %%
def value_fixer(value):
#     Make all upper/lower case of 'road|cross|main' to Road
    re_road = re.compile(re.escape('road'), re.IGNORECASE)
    re_main = re.compile(re.escape('main'), re.IGNORECASE)
    re_cross = re.compile(re.escape('cross'), re.IGNORECASE)
    if re.search('road', value, re.IGNORECASE):
        value = re_road.sub('Road',value)
    if re.search('cross', value, re.IGNORECASE):
        value = re_road.sub('Cross',value)
    if re.search('main', value, re.IGNORECASE):
        value = re_road.sub('Main',value)

#     Fix Rd or Rd. to Road
#     Added a space so as to avoid considering 'rd' as a part of '3rd' and only taking abc rd.
    re_rd_period = re.compile(re.escape(' rd\.'), re.IGNORECASE)
    re_rd = re.compile(re.escape(' rd'), re.IGNORECASE)
    if re.search(' rd\.', value, re.IGNORECASE):
        value = re_rd_period.sub(' Road', value)
    elif re.search(' rd', value, re.IGNORECASE):
        value = re_rd.sub(' Road', value)


#     Fix mn or mn. to Main
    re_mn_period = re.compile(re.escape('mn.'), re.IGNORECASE)
    re_mn = re.compile(re.escape('mn'), re.IGNORECASE)
    if 'Main' not in value:
        if re.search('th mn\.', value, re.IGNORECASE) or re.search('st mn\.', value, re.IGNORECASE) or re.search('nd mn\.', value, re.IGNORECASE) or re.search('rd mn\.', value, re.IGNORECASE):
            value = re_mn_period.sub('Main', value)
        elif re.search('th mn', value, re.IGNORECASE) or re.search('st mn', value, re.IGNORECASE) or re.search('nd mn', value, re.IGNORECASE) or re.search('rd mn', value, re.IGNORECASE):
            value = re_mn.sub('Main', value)
    if 'Main Road' not in value:
        value = value.replace('Main','Main Road')

#     Fix crs or Crs. or cros to Cross
    re_crs_period = re.compile(re.escape('crs.'), re.IGNORECASE)
    re_crs = re.compile(re.escape('crs'), re.IGNORECASE)
    re_cros = re.compile(re.escape('cros'), re.IGNORECASE)
    if 'Cross' not in value:
        if re.search('th crs\.', value, re.IGNORECASE) or re.search('st crs\.', value, re.IGNORECASE) or re.search('nd crs\.', value, re.IGNORECASE) or re.search('rd crs\.', value, re.IGNORECASE):
            value = re_crs_period.sub('Cross', value)
        elif re.search('th crs', value, re.IGNORECASE) or re.search('st crs', value, re.IGNORECASE) or re.search('nd crs', value, re.IGNORECASE) or re.search('rd crs', value, re.IGNORECASE):
            value = re_crs.sub('Cross', value)
        elif re.search('cros', value, re.IGNORECASE):
            value = re_crs.sub('Cross', value)
    if 'Cross Road' not in value:
        value = value.replace('Cross','Cross Road')

#     Remove everything after 'Road'. I.e. Removing area name for roads. Like 4th Main Road, Banashankri should become 4th Main Road.
    if 'Road' in value:
        value=value[0:value.index('Road')+4]
    return value

# %% [markdown]
# ## Key values that are not so good
#
# > 1. Some nodes value are given as 'traffic_signals' or 'bus_stop' It would be better if they didn't have _ seperating them. so maybe replace '_' with ' '
#
# > 2. Finally. Doing 1st step, might create an issue if we are changing a user name. User name eg. 'my_name' will change to 'my name' which shouldn't happen. So give an exception of changing value of key: 'created_by'
#
# > 3. Some key:'source' have value:'AND' -> Not sure what it refers to. But they appear a few times. Not sure if they need to be removed or not.

# %%
def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  # Handle secondary tags the same way for both node and way elements

    # YOUR CODE HERE
    count = 0
    count2 = 0
    if element.tag == 'node':
        node_attribs= {
            'id': int(element.attrib['id']),
            'user': element.attrib['user'].encode('utf-8').strip(),
            'uid': int(element.attrib['uid']),
            'version': element.attrib['version'].encode('utf-8').strip(),
            'lat': float(element.attrib['lat']),
            'lon': float(element.attrib['lon']),
            'timestamp': element.attrib['timestamp'].encode('utf-8').strip(),
            'changeset': int(element.attrib['changeset']),
        }
        for t in element:
            if t.tag=='tag':
#                 Pt. 1 and 2 of 'Key values that are not so good'
                if t.attrib['k'] is not 'created_by':
                    t.attrib['v'].replace('_',' ')
#                 We don't want to make name as :kn and type as 'name', so we make an alternative condition.
                if ':kn' not in t.attrib['k']:
                    if ':' in t.attrib['k']:
                        type = t.attrib['k'][0:t.attrib['k'].index(':')]
                        key = t.attrib['k'][t.attrib['k'].index(':')+1:]
                    else:
                        type = 'regular'
                        key = t.attrib['k']
                    value = value_fixer(t.attrib['v'].encode('utf-8').strip())
                    tags.append({
                        'id':int(element.attrib['id']),
                        'key': key.encode('utf-8').strip(),
                        'value': value,
                        'type': type.encode('utf-8').strip()
                        })
                else:
                    if ':' in t.attrib['k'][:t.attrib['k'].index(':kn')]:
                        type = t.attrib['k'][0:t.attrib['k'].index(':')]
                        key = t.attrib['k'][t.attrib['k'].index(':')+1:]
                    else:
                        type = 'regular'
                        key = t.attrib['k']
                    value = value_fixer(t.attrib['v'].encode('utf-8').strip())
                    tags.append({
                        'id':int(element.attrib['id']),
                        'key': key.encode('utf-8').strip(),
                        'value': value,
                        'type': type.encode('utf-8').strip()
                        })
        result = {'node': node_attribs, 'node_tags': tags}
        return {'node': node_attribs, 'node_tags': tags}
    elif element.tag == 'way':
        way_attribs= {
            'id': int(element.attrib['id']),
            'user': element.attrib['user'].encode('utf-8').strip(),
            'uid': int(element.attrib['uid']),
            'version': element.attrib['version'].encode('utf-8').strip(),
            'timestamp': str(element.attrib['timestamp']),
            'changeset': int(element.attrib['changeset']),
        }
        n=0
        for t in element:
            if t.tag=='tag':
#                 Pt. 1 and 2 of 'Key values that are not so good'
                if t.attrib['k'] is not 'created_by':
                    t.attrib['v'].replace('_',' ')
                if ':kn' not in t.attrib['k']:
                    if ':' in t.attrib['k']:
                        type = t.attrib['k'][0:t.attrib['k'].index(':')]
                        key = t.attrib['k'][t.attrib['k'].index(':')+1:]
                    else:
                        type = 'regular'
                        key = t.attrib['k']
                    value = value_fixer(t.attrib['v'].encode('utf-8').strip())
                    tags.append({
                        'id':int(element.attrib['id']),
                        'key': key.encode('utf-8').strip(),
                        'value': value,
                        'type': type.encode('utf-8').strip()
                        })
                else:
#                     If tag is of local language kannada, then :kn must not be in the key. 
                    if ':' in t.attrib['k'][:t.attrib['k'].index(':kn')]:
                        print 'tag: ', t
                        print t.attrib['k']
                        print "format: type:key:language 2"
                        print t.attrib['k']
                        type = t.attrib['k'][0:t.attrib['k'].index(':')]
                        key = t.attrib['k'][t.attrib['k'].index(':')+1:]
                        print 'type:', type
                        print 'key:', key
                        print 'value: ', value_fixer(t.attrib['v'].encode('utf-8').strip())
                    else:
                        print 'tag: ', t
                        print t.attrib['k']
                        print "format key:language 2"
                        print t.attrib['k']
                        type = 'regular'
                        key = t.attrib['k']
                        print 'type:', type
                        print 'key:', key
                        print 'value: ', value_fixer(t.attrib['v'].encode('utf-8').strip())
                    value = value_fixer(t.attrib['v'].encode('utf-8').strip())
                    tags.append({
                        'id':int(element.attrib['id']),
                        'key': key.encode('utf-8').strip(),
                        'value': value,
                        'type': type.encode('utf-8').strip()
                        })
            elif t.tag=='nd':
                way_nodes.append({
                    'id': element.attrib['id'],
                    'node_id': t.attrib['ref'],
                    'position': n
                })
                n += 1
                
        result = {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}

# %%
# USED CODE FROM THE FINAL CHAPTER OF THE DATA WRANGLING COURSE
# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()

# %%
# USED CODE FROM THE FINAL CHAPTER OF THE DATA WRANGLING COURSE
# ================================================== #
#               Helper Functions                     #
# ================================================== #
def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_string = pprint.pformat(errors)
        raise Exception(message_string.format(field, error_string))

# %%
# USED CODE FROM THE FINAL CHAPTER OF THE DATA WRANGLING COURSE

# ================================================== #
#               Helper Functions                     #
# ================================================== #
class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)

# %%
# USED CODE FROM THE FINAL CHAPTER OF THE DATA WRANGLING COURSE
# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])

# %%
process_map(OSM_PATH, validate=False)
# Out:
# tag:  <Element 'tag' at 0x10412c930>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಹಾತ್ಮ ಗಾಂಧಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8240>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕುಮಾರ ಕೃಪ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408f450>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408f1e0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d5a50>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ವಿಕ್ಟೊರಿಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d5fc0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಲಾಲಬಾಗ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045e0b70>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕೆಂಗೇರಿ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045ddf00>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕೆಂಗೇರಿ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104123900>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಲ್ಲತ್ತಹಳ್ಳಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c810>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಲಾಲ್‌ಬಾಗ್ ಸಸ್ಯೋದ್ಯಾನ
# tag:  <Element 'tag' at 0x10412c330>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕೃಷ್ಣ ರಾವ ಉದ್ಯಾನ
# tag:  <Element 'tag' at 0x10408f390>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕೆಂಗಲ್ ಹನುಮಂತಯ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408fe40>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ವಾಣಿ ವಿಲಾಸ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130510>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಬನ್ನೇರುಘಟ್ಟ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1041301e0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ದೊಡ್ಡಬಳ್ಳಾಪುರ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d5fc0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕಸ್ತೂರ್ಬಾ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414b9c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕಬ್ಬನ್ ಉದ್ಯಾನ
# tag:  <Element 'tag' at 0x1040de030>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ದೇವರಚಿಕ್ಕನಹಳ್ಳಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045e0bd0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಹುಳಿಮಾವು ಕೆರೆ
# tag:  <Element 'tag' at 0x1040d0810>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಹುಳಿಮಾವು ಕೆರೆ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104123870>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಹುಳಿಮಾವು ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c5d0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಹುಳಿಮಾವು ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1042289f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಬನ್ನೇರುಘಟ್ಟ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1042284e0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಹೊರ ವರ್ತುಲ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d07b0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಹೊಸೂರು ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045ddd80>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2360>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕಡಿದಾಳ್ ಮಂಜಪ್ಪ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130a20>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕಾನ್ವೆಂಟ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104228ae0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಬ್ರಿಗೇಡ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104228e40>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಬ್ರಿಗೇಡ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d5810>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಬ್ರಿಗೇಡ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414b930>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸೇಂಟ್ ಮಾರ್ಕ್ಸ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040de3f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಲಾವೆಲ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040de7e0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕಂಟೀರವ ಕ್ರೀಡಾಂಗಣ
# tag:  <Element 'tag' at 0x104123870>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ವೆಲ್ಲಿಂಗ್ಟಂನ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104123db0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಜಯಚಾಮರಾಜೇಂದ್ರ ಓಡೆಯರ್  ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412ca20>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನೊರಿಸ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412cd50>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ವಾಲ್ಕರ್ ಲೇನ್
# tag:  <Element 'tag' at 0x1040d8a50>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೫ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408fae0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮೈಸೂರು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1042288a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಪುಟ್ಟಲಿಂಗಯ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d5900>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೦ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414b390>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕೆಂಚನಹಳ್ಳಿ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f1e40>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಜವಹರಲಾಲ್ ನೆಹರೂ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045e0750>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ರಾಷ್ಟ್ರೀಯ ವಿದ್ಯಾಲಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040b5270>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ರಾಷ್ಟ್ರೀಯ ವಿದ್ಯಾಲಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8120>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೯ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408f270>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಪಟ್ಟಣಗೆರೆ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d55a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414b510>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೪ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f1960>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮೌಂಟ್ ಜಾಯ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040de840>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045e0d50>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೬ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d0690>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೬ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045d7f00>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೯ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2fc0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೭ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e27e0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೮ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104123ba0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಹನುಮಂತನಗರ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c930>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೦ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d80f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೯ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8270>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130540>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೪ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104228630>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೯ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104228180>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೭ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414b720>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಗಂಗಮ್ಮ ದೇವರ ಬೀದಿ
# tag:  <Element 'tag' at 0x1040de8d0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೮ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040de6f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೧ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040de0c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೯ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d0de0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೨ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2c90>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೯ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e21e0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೭ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1041235d0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೭ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c810>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೫ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412ca80>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೬ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8ea0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೨ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8720>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೮ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d87e0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೬ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408f9c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೭ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1041309f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೪ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130960>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1041304e0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104228f60>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d5360>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಆಲ್ಬರ್ಟ್ ವಿಕ್ಟರ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414b180>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೫ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414b2d0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಿಲ್ಲರ್ಸ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414b2a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ವೆಂಕಟಸ್ವಾಮಿ ನೈದು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040dea20>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನಂದಿದುರ್ಗ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045e05a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045e06f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045dd960>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಹೊಸಹಳ್ಳಿ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045dd990>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೪ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d0630>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೭ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104123990>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೬ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8d80>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಲಕ್ಷೀಶ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408f990>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮೂಲೆಯಿಂದ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130db0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಅರ್ಮುಗಮ್ ಮುದಲಿಯರ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130990>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಆಲ್ಬರ್ಟ್ ವಿಕ್ಟರ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1042285a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಆಲ್ಬರ್ಟ್ ವಿಕ್ಟರ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104228b70>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಪೈಲ್ವಾನ್ ಕೃಷ್ಣಪ್ಪ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d57e0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಜಿಲ್ಲೆ ಕಛೇರಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f15a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಡಾ. ವಿಷ್ಣುವರ್ಧನ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f1570>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f1810>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಲಾಲ್‌ಬಾಗ್‌ ಕೋಟೆ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040de5a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸಿದ್ದಯ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040de630>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಬಿಟಿಎಸ್ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045e0b40>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೭ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045e09c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೫ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045e02a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೪ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1041233f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104123780>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೬ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c150>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೪ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c720>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೬ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c0c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d89f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408fd20>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೦ನೇ ಸಿ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130b40>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನ್ಯಾಶನಲ್ ಪ್ರೌಡ ಶಾಲಾ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130630>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಹಳೆ ಸುಂಕಲ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1041305d0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕುಂಬಾರಗುಂಡಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d50f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d5f90>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d5f60>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೪ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414be10>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಉಸ್ಮಾನ್ ಖಾನ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f1840>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನರಸಿಂಹರಾಜ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2210>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಹಾರಾಷ್ಟ್ರ ಮಹಿಳ ವಿದ್ಯಾಲಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104123690>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಡಿಸ್ಪೆನ್ಸರಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104123e10>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412cf00>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8c60>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೯ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8030>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೪ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8180>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೫ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8750>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೬ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408f570>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408f630>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೭ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408f3f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೮ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1041302a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೦ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e20f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಶ್ರೀರಾಮ ಮಂದಿರ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104123630>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಗೋವಿಂದಪ್ಪ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104123930>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕೃಷ್ಣರಾವ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c780>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಶ್ರೀರಾಮ ಮಂದಿರ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8c00>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಹಳೆ ಪಶುವೈದ್ಯಕೀಯ ಆಸ್ಪತ್ರೆ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408f120>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಪುಟ್ಟಣ್ಣ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408f6c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ರತ್ನ ವಿಲಾಸ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130570>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ರತ್ನ ವಿಲಾಸ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130cf0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104228e70>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಅಂಜನೇಯ ದೇವಸ್ಥಾನ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104228ba0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಪೋಲಿಸ್ ಠಾಣೆ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d5510>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸನ್ನಿಧಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d58a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f1bd0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೩ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f1b70>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಗಣೇಶ ದೇವಸ್ಥಾನ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2f60>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಗಾಂಧಿ ಬಜಾರ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8690>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d89c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೫ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d5960>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸುಬ್ರಮಣ್ಯಪುರ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d5930>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ವೈಟ್‌ಫೀಲ್ಡ್‌ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414bba0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕೆನ್ಸಿಂಗಟನ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414b1e0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೦೦ ಅಡಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f1a50>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಒಳ ವೃತ್ತ
# tag:  <Element 'tag' at 0x1040f13f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040defc0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಪಟ್ಟಂದೂರು ಅಗ್ರಹಾರ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045dd180>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಚಿನ್ಮಯ ಆಸ್ಪತ್ರೆ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045d7cf0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2360>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ರಿಚ್ಮಂಡ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2a20>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ವರ್ತೂರು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c5a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ರಿಚ್ಮಂಡ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c510>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೬ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412ce40>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408f390>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408fb10>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ರಾಮಚಂದ್ರ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104228120>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಬೆಂಗಳೂರು - ಸಲೇಂ ರೈಲು
# tag:  <Element 'tag' at 0x1040d5810>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧ನೇ ಏ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d5390>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೮೦ ಅಡಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414b3c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೫ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414bed0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ತಿಪ್ಪಸಂದ್ರ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f19c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೮ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040de270>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸರ್ಜಾಪುರ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040ded80>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಒಳ ವರ್ತುಲ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045dd090>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೫ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d04b0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕಾಸೆಲ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045e09f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045e04e0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೨ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045cec00>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045d7a50>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2d20>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೧ ಏ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2de0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೪ ಬೀ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1041230f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೫ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1041236c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೩ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414ba80>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕುಡ್ಲು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f12a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಹರಳೂರು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045e0480>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8f90>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕುಡ್ಲು ಶಾಲೆ
# tag:  <Element 'tag' at 0x104228300>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕೇಂದ್ರ ಕಾರಾಗೃಹ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104228a20>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಹೊಸ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d5060>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಜೀವನಭೀಮನಗರ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d5ab0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೩ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414bfc0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೨ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f1660>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನೈಸ್‌ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045caed0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನೈಸ್ ವರ್ತುಲ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045dd660>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಗೊಟ್ಟಿಗೆರೆ ಗೆರೆ
# tag:  <Element 'tag' at 0x1045e0900>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೦ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2360>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನೈಸ್ ವರ್ತುಲ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104123120>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನೈಸ್‌ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104123cc0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನೈಸ್‌ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c630>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನೈಸ್ ವರ್ತುಲ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412cf30>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನೈಸ್ ವರ್ತುಲ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408fd50>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನೈಸ್ ವರ್ತುಲ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8540>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನೈಸ್ ವರ್ತುಲ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8ab0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನೈಸ್ ವರ್ತುಲ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1042288d0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೨ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d5750>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೪ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d51b0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೨ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414be70>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೫ ಬೀ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414bbd0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೭ ಏ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414bb70>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೭ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d0ae0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೬ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045d32a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೯ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040de6f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೭ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040de600>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೯ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040de450>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೯ ಏ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040de570>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೯ ಬೀ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f1900>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೦ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045e06c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೫ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10463ff60>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೧ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e25a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೦ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2270>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೯ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2e40>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೯ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e20f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೩ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104123cc0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೫ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1041239c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೫ ಏ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130f90>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೬ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130150>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೯ ಏ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130810>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೯ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c630>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೨ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412cea0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೮ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412ca50>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f1b40>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಅಮೃತ ವಿಶ್ವ ವಿದ್ಯಾಪಿಠಂ
# tag:  <Element 'tag' at 0x1040f19f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಅಮೃತ ವಿಶ್ವ ವಿದ್ಯಾಪಿಠಂ
# tag:  <Element 'tag' at 0x10408fbd0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೫ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408ffc0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408ff30>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8a20>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8030>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧ ಏ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8f00>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಜೋಡಿ ರಸ್ತೆ, ಇಂದಿರನಗರ
# tag:  <Element 'tag' at 0x104228db0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಆಶೋಕ ಸ್ತಂಭ ವೃತ್ತ
# tag:  <Element 'tag' at 0x10414b030>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಅಮೃತನಗರ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10463f030>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕೊತ್ತನೂರು ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045dd660>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೬ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045d7a50>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೪ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2c90>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೭ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2ae0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೬ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412cea0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೫ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c1b0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130150>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಬೆಳ್ಳಂದೂರು ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8a80>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104228600>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಹೊಸಕೆರೆಹಳ್ಳಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414b6f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೪ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414b990>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಹಡ್ಸನ್ ವೃತ್ತ
# tag:  <Element 'tag' at 0x1045d3d20>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೪ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f1f00>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನಾಗರಭಾವಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040de090>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕಸ್ತೂರ್ಬಾ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040ded80>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸೇಂಟ್ ಮಾರ್ಕ್ಸ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045e0f60>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಬೌರಿಂಗ್ ಆಸ್ಪತ್ರೆ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2330>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2c90>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2990>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸಾಯಿಬಾಬಾ ಮಂದಿರ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c690>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕೇಂಬ್ರಿಡ್ಜ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c9c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಜೋಗುಪಾಳ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130090>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130930>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೪ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104228b40>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನೀಲಾದ್ರಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040dea20>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ತಿಮ್ಮಯ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040de810>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಶಿವಾಜಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040de570>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಚಾಂದ್ನಿ ಚೌಕ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045e0ea0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ದೇವರಾಜ ಅರಸ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104612ea0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e26f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ರಾಮನ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2e40>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಾರ್ಗೋಸ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c330>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಹೆಬ್ಬಾಳ ಕೆರೆ
# tag:  <Element 'tag' at 0x10412c6c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮೋಹನ ಕುಮಾರ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104123b70>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಹೆಣ್ಣೂರು- ಬಾಗಲೂರು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f1c60>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಗ್ರಾತ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414b8d0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೦೦ ಅಡಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104228030>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d5630>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ವರ್ತೂರು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8120>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೯ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d88d0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೬ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040de660>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೦ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040dea50>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೨ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040deea0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೭ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045e06f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೩ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045e0600>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೪ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040b5270>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e21b0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e29f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1041308d0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130330>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412ce40>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೧ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c510>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೩ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c720>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೨ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408fde0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೦ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f1f90>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಹೊರ ವರ್ತುಲ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414bb10>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೩ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414be10>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೧ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414b3f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೦ನೇ 'ಎ' ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414bcf0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೦ ಏ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045ca600>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೭ ಬೀ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1042281b0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೮ ಬೀ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104228270>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೮ ಬೀ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104228870>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೮ ಸೀ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104228990>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೮ ಈ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d80f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೧ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8c00>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೧ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040dec00>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೯ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040dea50>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೭ ಏ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040deea0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೯ ಏ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040ded50>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೯ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1046120c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೮ ಏ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1046123c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೯ ಏ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040b5270>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೦ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2ea0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೩ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2a20>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೩ ಏ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2cc0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೪ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2a50>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೪ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1041302a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೪ನೇ 'ಎ' ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130600>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೫ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130e40>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೫ನೇ 'ಎ' ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1041306c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೬ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c180>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೯ನೆ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408f060>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೪೦ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408fe40>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೬ ಸೀ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045d3960>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೩ ಏ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104123570>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಅಗರ ಕೆರೆ
# tag:  <Element 'tag' at 0x104123fc0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೮ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104123810>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೦ ಬೀ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104123a50>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೦ ಏ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f1060>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೦ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f1900>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೯ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f1120>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೯ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f1540>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೦ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414bb70>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೧ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414b3c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨೧ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414bd20>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೪ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414bdb0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೪ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104228210>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೪ ಎ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104228a80>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d5600>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೭ ಸಿ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d55d0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕೋರಮಂಗಲ ೩ನೇ ಬ್ಲಾಕ್
# tag:  <Element 'tag' at 0x1040d86f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಹಾಯೋಗಿ ವೇಮನ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8d80>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040de810>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೫ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045d7b10>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೪ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1041301b0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೨ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130b70>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೫ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c1b0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c480>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨ ಎ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408ffc0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೫ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045d3e10>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೪ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104123b70>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೩ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104123990>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f1120>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೮ ಏ ಮುಖ್ಯರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040f1480>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೫ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414bc00>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414bed0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೪ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414b060>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10414ba20>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045ca600>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೬ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104228de0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೫ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104228390>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೪ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d5900>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040d8ea0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೮ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040def60>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೪೧ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10463fe70>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೪೭ನೇ ಅಪ್ಪ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040e2330>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೭ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104130d50>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸಾರಕ್ಕಿ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c450>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೦ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10412c8a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೮ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408fe10>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩೨ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045d30c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೫ನೇ ಏ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104123d20>
# name:kn
# format key:language 2
# name:kn
# ...
# tag:  <Element 'tag' at 0x1043ac150>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಾಗಡಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104531990>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ದಿನ್ನೂರು ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104531d20>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ದಿನ್ನೂರು ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104531e10>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ದಿನ್ನೂರು ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10451b4b0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ದಿನ್ನೂರು ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10451b4e0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040aff90>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಬಳ್ಳಾರಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040af5a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಬಳ್ಳಾರಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103f8cc90>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ರಮಣ ಮಹರ್ಷಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103f8cb10>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ರಮಣ ಮಹರ್ಷಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103f8c690>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸಾಂಕಿ ಕೆರೆ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10463fb70>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ವ್ಯಾಲಿಕಾವಲ್ ಮುಖ್ಯರಸ್ತೆ
# tag:  <Element 'tag' at 0x10463f1b0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103f9ae70>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103f9a810>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ದತ್ತಾತ್ರೇಯ ದೇವಸ್ಥಾನ ಬೀದಿ
# tag:  <Element 'tag' at 0x103f9a690>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ದತ್ತಾತ್ರೇಯ ದೇವಸ್ಥಾನ ಬೀದಿ
# tag:  <Element 'tag' at 0x103f9a8d0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೫ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045d3330>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಹಾಕವಿ ಕುವೆಂಪು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10450e2a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಹಾಕವಿ ಕುವೆಂಪು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10450e660>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಹಾಕವಿ ಕುವೆಂಪು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10450eb70>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೯ನೇ ಮುಖ್ಯ ರಸ್ತೆ (ಗೊರೂರ್ ರಾಮಸ್ವಾಮಿ ಐಯಂಗಾರ್ ರಸ್ತೆ )
# tag:  <Element 'tag' at 0x10450e1e0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೭ನೇ ಮುಖ್ಯ ರಸ್ತೆ (ಎಸ ನಿಜಲಿಂಗಪ್ಪಾ ರಸ್ತೆ )
# tag:  <Element 'tag' at 0x1045dd9f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಾಗಡಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045dd960>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸಿದ್ದಯ್ಯ ಪುರಾಣಿಕ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104517720>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಾಗಡಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10451b3f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10451b060>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10451be40>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104617e40>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೮ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040aff30>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೮ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040af8a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೨ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040af630>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೨ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040af180>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೨ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103f8c180>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೨ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103f8c570>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕಾರ್ಡ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103f8cc60>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕಾರ್ಡ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103f8c270>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕಾರ್ಡ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103f8cd80>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೨ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10463fc00>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೯ನೇ ಮುಖ್ಯ ರಸ್ತೆ (ಗೊರೂರ್ ರಾಮಸ್ವಾಮಿ ಐಯಂಗಾರ್ ರಸ್ತೆ )
# tag:  <Element 'tag' at 0x10463fe70>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೯ನೇ ಮುಖ್ಯ ರಸ್ತೆ (ಗೊರೂರ್ ರಾಮಸ್ವಾಮಿ ಐಯಂಗಾರ್ ರಸ್ತೆ )
# tag:  <Element 'tag' at 0x10463f9f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೯ನೇ ಮುಖ್ಯ ರಸ್ತೆ (ಗೊರೂರ್ ರಾಮಸ್ವಾಮಿ ಐಯಂಗಾರ್ ರಸ್ತೆ )
# tag:  <Element 'tag' at 0x10463fcc0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮೋದಿ ಆಸ್ಪತ್ರೆ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103f9adb0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಹಾಕವಿ ಕುವೆಂಪು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103f9ac60>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಹಾಕವಿ ಕುವೆಂಪು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103f9ac00>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಹಾಕವಿ ಕುವೆಂಪು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045d3810>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೫ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045d3a50>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೫ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10450e6f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸಂಪಿಗೆ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045d76c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸುಬೇದಾರ್ ಛತ್ರಂ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045d72d0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಗೋವಿಂದ ವಿಟ್ಟಲ ಭಾವೆ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10455d150>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನೆಹರು ವೃತ್ತ
# tag:  <Element 'tag' at 0x10408f3f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನೆಹರು ವೃತ್ತ
# tag:  <Element 'tag' at 0x10408f0c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ದೇವರಾಜ ಅರಸು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045dd630>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ದೇವರಾಜ ಅರಸು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045dddb0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ರಾಜ ಭಾವನ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1043acfc0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ವೆಂಕಟಸ್ವಾಮಿ ನಯುಡು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1043ace10>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಶಿವಾಜಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10451b930>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕೆಂಗೇರಿ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10451b180>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಲ್ಲತ್ತಹಳ್ಳಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104617450>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಲ್ಲತ್ತಹಳ್ಳಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040afb40>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೮ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040afba0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೮ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040afc00>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೪ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103f8c570>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೪ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103f8cc60>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೭ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103f8c3f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸಂಪಿಗೆ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103f8c240>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸಂಪಿಗೆ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10463f390>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸಂಪಿಗೆ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10463fc90>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸಂಪಿಗೆ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103f9a210>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸಂಪಿಗೆ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103f9ad80>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸಂಪಿಗೆ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045d36f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕಾರ್ಡ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10450e930>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನಾಗರಭಾವಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10450e330>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನಾಗರಭಾವಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10450ec60>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನಾಗರಭಾವಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045d7a20>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನಾಗರಭಾವಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10455de10>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನಾಗರಭಾವಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10431a2d0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನಾಗರಭಾವಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408f8d0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನಾಗರಭಾವಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408f2a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನಾಗರಭಾವಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045ddea0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನಾಗರಭಾವಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045dd7b0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನಾಗರಭಾವಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045dd2d0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನಾಗರಭಾವಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104531750>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1043ac900>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೩ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1043accc0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103f8cf30>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ದಕ್ಷಿಣ ಪಿನಾಕಿನಿ
# tag:  <Element 'tag' at 0x1045184b0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ದಕ್ಷಿಣ ಪಿನಾಕಿನಿ
# tag:  <Element 'tag' at 0x103f9a990>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಥಣಿಸಂದ್ರ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408f6c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಥಣಿಸಂದ್ರ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408ffc0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045dd330>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045d7b70>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸುರಂಜನ್ ದಾಸ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10408f9f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ನಮ್ಮ ಮೆಟ್ರೋ
# tag:  <Element 'tag' at 0x1045315d0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಾಗಡಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045319c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಾಗಡಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1043ac690>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಾಗಡಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1043aca20>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಾಗಡಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1043acf30>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ತುಮಕೂರು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040aff90>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ತುಮಕೂರು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045dda20>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೭ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045c40f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸರ್ಕಾರಿ ಶಾಲೆ
# tag:  <Element 'tag' at 0x10451b360>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಹೊಸೂರು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104508d50>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಹೊಸೂರು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10418e780>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಹೊಸೂರು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103fc7510>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕ್ರಿಸ್ತ ಶಾಲೆ
# tag:  <Element 'tag' at 0x1046171b0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮೋದಿ ಆಸ್ಪತ್ರೆ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1046170f0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮೋದಿ ಆಸ್ಪತ್ರೆ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1043acf60>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮೋದಿ ಆಸ್ಪತ್ರೆ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1043ac690>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045dd060>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೨ನೇ ಅಡ್ಡ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1040b5930>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮಾರೇನಹಳ್ಳಿ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103fc7240>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೭ನೇ ಸುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x103fc7210>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಬೆಂಗಳೂರು-ಮೈಸೂರು ಹೆದ್ದಾರಿ
# tag:  <Element 'tag' at 0x1045c4840>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕೃಷ್ಣ ರಾಜೇಂದ್ರ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045c4390>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕೃಷ್ಣ ರಾಜೇಂದ್ರ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045c4c30>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಸುಲ್ತಾನ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045c4c90>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕಾಟನ್‌ಪೇಟೆ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10450e030>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮೈಸೂರು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x10450ee40>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಕಾರ್ಡ್ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104523de0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಮೈಸೂರು ರಸ್ತೆ
# tag:  <Element 'tag' at 0x104523750>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೧ನೇ ಮುಖ್ಯ ರಸ್ತೆ
# tag:  <Element 'tag' at 0x1045c4ae0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೭ನೇ ಮುಖ್ಯ ರಸ್ತೆ (ಎಸ ನಿಜಲಿಂಗಪ್ಪಾ ರಸ್ತೆ )
# tag:  <Element 'tag' at 0x1045d72a0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ೧೭ನೇ ಮುಖ್ಯ ರಸ್ತೆ (ಎಸ ನಿಜಲಿಂಗಪ್ಪಾ ರಸ್ತೆ )
# tag:  <Element 'tag' at 0x10408f3c0>
# name:kn
# format key:language 2
# name:kn
# type: regular
# key: name:kn
# value:  ಪಟ್ಟಣಗೆರೆ ಮುಖ್ಯ ರಸ್ತೆ

# %% [markdown]
# # PUSH csv to SQLITE DB

# %%
# Creates SQL Table
def create_table(create_table_query,conn):
    c = conn.cursor()
    c.execute(create_table_query)
    conn.commit()

# %%
# Reads csv
def read_csv(csv_file):
    with open(csv_file, "rb") as f:
        reader = csv.reader(f)
        header = reader.next()
        data = [row for row in reader]
        return header,data

# %%
# adds each row of csv into sql table
def add_into_table(csv_file):
    c = conn.cursor()
    table_name = csv_file[csv_file.index('/')+1:csv_file.index('.csv')]
    header,data = read_csv(csv_file)
    header_string = '(\"'+ '\", \"'.join(str(x) for x in header)+'\")'
    for row in data:
        data_string = '(\"'+ '\", \"'.join(str(x).replace('\"','').replace('\'','') for x in row)+'\")'
        query_string = "INSERT INTO "+table_name+header_string+" VALUES "+data_string
        try:
            c.execute(query_string)
        except:
            print 'error query: ', query_string
            conn.commit()
            return
    conn.commit()

# %%
conn = sqlite3.connect('bengaluru_map.db')
# Create tables for each csv file
# Node
create_table_query = '''CREATE TABLE IF NOT EXISTS node(id INTEGER, lat REAL, lon REAL, user STRING, uid INTEGER,
                    version STRING, changeset INTEGER, timestamp STRING, PRIMARY KEY(id ASC))'''
create_table(create_table_query,conn)

# Node_tags
conn = sqlite3.connect('bengaluru_map.db')
create_table_query = '''CREATE TABLE IF NOT EXISTS node_tags(id INTEGER, key STRING, value STRING, type STRING,
                    FOREIGN KEY(id) REFERENCES node(id))'''
create_table(create_table_query,conn)
# way
create_table_query = '''CREATE TABLE IF NOT EXISTS way(id INTEGER, user STRING, uid INTEGER, version STRING,
                    changeset INTEGER, timestamp STRING, PRIMARY KEY(id ASC))'''
create_table(create_table_query,conn)

# way_nodes
create_table_query = '''CREATE TABLE IF NOT EXISTS way_nodes(id INTEGER, node_id INTEGER, position INTEGER, 
                    FOREIGN KEY(id) REFERENCES way(id), FOREIGN KEY(node_id) REFERENCES node(id))'''
create_table(create_table_query,conn)

# way_tags
create_table_query = '''CREATE TABLE IF NOT EXISTS way_tags(id INTEGER, key STRING, value STRING, type STRING,
                    FOREIGN KEY(id) REFERENCES way(id))'''
create_table(create_table_query,conn)

conn.close()

# %%
# To drop table incase you want to try again
# conn = sqlite3.connect('bengaluru_map.db')
# drop_query = '''DROP TABLE node_tags'''
# create_table(drop_query,conn)

# %%
# Build connection
conn = sqlite3.connect('bengaluru_map.db')
c = conn.cursor()
# Add data into table:
# Node
add_into_table("bangalore/node.csv")
# Node_tags
add_into_table("bangalore/node_tags.csv")
# way
add_into_table("bangalore/way.csv")
# way_nodes
add_into_table("bangalore/way_nodes.csv")
# way_tags
add_into_table("bangalore/way_tags.csv")
conn.close()

# %% [markdown]
# # QUERIES

# %% [markdown]
# ### The number of rows that were written in 'Kannada', the local language:

# %%
conn = sqlite3.connect('bengaluru_map.db')
c = conn.cursor()
result = c.execute("SELECT COUNT(*) FROM node_tags WHERE key LIKE '%:kn%'")
for row in result:
    print row
conn.close()
# Out:
# (4444,)

# %%
conn = sqlite3.connect('bengaluru_map.db')
c = conn.cursor()
result = c.execute("SELECT COUNT(*) FROM way_tags WHERE key LIKE '%:kn%'")
for row in result:
    print row
conn.close()
# Out:
# (8109,)

# %% [markdown]
# ### The most popular amenities in Bangalore:
# > There are a lot of restaurants, cafes and fastfood joints around bangalore. So we can explore them and also the find the more popular banks

# %%
# USED CODE FROM THE SAMEPLE CODE GIVEN IN https://gist.github.com/carlward/54ec1c91b62a5f911c42#map-area
# Questions - Most popular Amenities in bangalore
conn = sqlite3.connect('bengaluru_map.db')
c = conn.cursor()
result = c.execute("SELECT value,count(*) FROM node_tags WHERE key LIKE '%amenity%' GROUP BY value ORDER BY count(*) DESC LIMIT 10")
for row in result:
    print row
conn.close()
# Out:
# (u'restaurant', 1697)
# (u'atm', 799)
# (u'bank', 743)
# (u'place_of_worship', 701)
# (u'pharmacy', 553)
# (u'fast_food', 515)
# (u'hospital', 454)
# (u'school', 371)
# (u'cafe', 350)
# (u'fuel', 282)

# %%
# MODIFIED CODE FROM THE SAMEPLE CODE GIVEN IN https://gist.github.com/carlward/54ec1c91b62a5f911c42#map-area
# Questions - Most popular Banks in India
conn = sqlite3.connect('bengaluru_map.db')
c = conn.cursor()
result = c.execute("SELECT node_tags.value, COUNT(*) as num FROM node_tags,(SELECT DISTINCT(id) FROM node_tags WHERE value LIKE '%bank%') as banknodes ON node_tags.id=banknodes.id WHERE node_tags.key IN ('name','operator','brand') AND node_tags.value LIKE '%bank%' GROUP BY node_tags.value ORDER BY num DESC LIMIT 10")
for row in result:
    print row
conn.close()
# Out:
# (u'State Bank of India', 194)
# (u'Canara Bank', 126)
# (u'ICICI Bank', 105)
# (u'Axis Bank', 104)
# (u'HDFC Bank', 89)
# (u'Corporation Bank', 48)
# (u'Karnataka Bank', 48)
# (u'Vijaya Bank', 42)
# (u'Syndicate Bank', 31)
# (u'Citibank', 30)

# %%
# USED CODE FROM THE SAMEPLE CODE GIVEN IN https://gist.github.com/carlward/54ec1c91b62a5f911c42#map-area
# Questions - Food in bangalore - The more popular cuisines
conn = sqlite3.connect('bengaluru_map.db')
c = conn.cursor()
result = c.execute("SELECT value,count(*) as quantity FROM node_tags,(SELECT DISTINCT(id) FROM node_tags WHERE value IN ('restaurant','cafe','fast_food')) as foodnodes ON node_tags.id=foodnodes.id WHERE key IN ('cuisine') GROUP BY value ORDER BY quantity DESC LIMIT 10")
# u'cuisine'
# result=c.execute("SELECT DISTINCT(id) FROM node_tags WHERE value IN ('restaurant','cafe','fast_food')")
for row in result:
    print row
conn.close()
# Out:
# (u'regional', 368)
# (u'indian', 292)
# (u'pizza', 90)
# (u'vegetarian', 89)
# (u'chinese', 78)
# (u'ice_cream', 52)
# (u'coffee_shop', 50)
# (u'burger', 45)
# (u'international', 31)
# (u'italian', 29)

# %%
# Number of roads in bangalore
conn = sqlite3.connect('bengaluru_map.db')
c = conn.cursor()
result = c.execute("SELECT count(*) FROM way_tags WHERE value LIKE '%Road%'")
for row in result:
    print row
conn.close()
# Out:
# (10325,)

# %% [markdown]
# # Top 10 Node id where highest number of ways intersect

# %%
conn = sqlite3.connect('bengaluru_map.db')
c = conn.cursor()
node_through_which_highest_way_pass = "(SELECT node_id,count(*) FROM way_nodes GROUP BY node_id ORDER BY count(*) DESC LIMIT 10) as busy_nodes"
info_about_that_node = "SELECT id FROM node,"+node_through_which_highest_way_pass+" ON busy_nodes.node_id=node.id WHERE node.id=busy_nodes.node_id "
result = c.execute(info_about_that_node)
op=[]
for row in result:
    op.append(row[0])
conn.close()

# %%
print op
# Out:
# [3676386504, 3756817769, 3756817774, 3676386503, 3750785900, 3751654300, 3756817768, 3676374899, 3676374909, 3750785901]

# %%
# To find out more about these nodes, we investigated further. We find no node tags. 
tags_of_those_nodes = "SELECT * FROM node_tags,("+info_about_that_node+") as main_nodes WHERE main_nodes.id=node_tags.id"
conn = sqlite3.connect('bengaluru_map.db')
c = conn.cursor()
result = c.execute(tags_of_those_nodes)
for row in result:
    print row
conn.close()

# %% [markdown]
# ## Vidhan Souda
# > There were no information on these nodes, so I went through google maps entering these lat,lons.
# > Found something interesting. All these nodes are a part of or few minutes away from 'Vidhan Souda' which is the state legislature building of karnataka. Which makes sense. There might be a lot of ways - including the walking paths, buildings, walls, metro, roads that pass through it, roads that go around it, service roads, etc.

# %% [markdown]
# ## Additional Statistics :
# ### Number of Rows
# 1. Number of nodes: 2882959
# 1. Number of node_tags: 93243
# 1. Number of ways: 660784
# 1. Number of way_nodes: 3576371
# 1. Number of way_tags: 723631
#
# ### Size of each CSV file it was retreived from
# 1. Size of node.csv file: 241.3 MB
# 1. Size of node_tags.csv file: 3.7 MB
# 1. Size of way.csv file: 40.3 MB
# 1. Size of way_nodes.csv file: 85.8 MB
# 1. Size of way_tags.csv file: 24.1 MB

# %%
conn = sqlite3.connect('bengaluru_map.db')
c = conn.cursor()
result = c.execute("SELECT COUNT(*) FROM node")
for row in result:
    print row
conn.close()
# Out:
# (2882959,)

# %%
conn = sqlite3.connect('bengaluru_map.db')
c = conn.cursor()
result = c.execute("SELECT COUNT(*) FROM node_tags")
for row in result:
    print row
conn.close()
# Out:
# (93243,)

# %%
conn = sqlite3.connect('bengaluru_map.db')
c = conn.cursor()
result = c.execute("SELECT COUNT(*) FROM way")
for row in result:
    print row
conn.close()
# Out:
# (660784,)

# %%
conn = sqlite3.connect('bengaluru_map.db')
c = conn.cursor()
result = c.execute("SELECT COUNT(*) FROM way_nodes")
for row in result:
    print row
conn.close()
# Out:
# (3576371,)

# %%
conn = sqlite3.connect('bengaluru_map.db')
c = conn.cursor()
result = c.execute("SELECT COUNT(*) FROM way_tags")
for row in result:
    print row
conn.close()
# Out:
# (723631,)

# %%
# USED CODE FROM THE SAMEPLE CODE GIVEN IN https://gist.github.com/carlward/54ec1c91b62a5f911c42#map-area
# NUMBER OF UNIQUE USERS 
conn = sqlite3.connect('bengaluru_map.db')
c = conn.cursor()
result = c.execute("SELECT COUNT(DISTINCT(e.uid)) FROM (SELECT uid FROM node UNION ALL SELECT uid FROM way) e")
for row in result:
    print row[0]
conn.close()
# Out:
# 1999

# %%
# USED CODE FROM THE SAMEPLE CODE GIVEN IN https://gist.github.com/carlward/54ec1c91b62a5f911c42#map-area
# Highest contributing user
conn = sqlite3.connect('bengaluru_map.db')
c = conn.cursor()
result = c.execute("SELECT e.user, COUNT(*) as num FROM (SELECT user FROM node UNION ALL SELECT user FROM way) e GROUP BY e.user ORDER BY num DESC LIMIT 10")
for row in result:
    print row
conn.close()
# Out:
# (u'jasvinderkaur', 124900)
# (u'akhilsai', 118687)
# (u'premkumar', 115884)
# (u'saikumar', 114996)
# (u'shekarn', 98118)
# (u'PlaneMad', 94732)
# (u'vamshikrishna', 94275)
# (u'himalay', 88246)
# (u'himabindhu', 86844)
# (u'sdivya', 84998)
